# %% [markdown]
# ## RED WINE QUALITY PREDICTION
# In this project I used the red wine quality dataset from the UCL Machine Learning Repository. I used the 11 available features to predict the quality of red wine.
# The project is split in 4 parts:
# 1. Define the problem
# 2. Prepare Data
# 3. Spot Check Algorithms
# 4. Improve Results

# %% [markdown]
# ### 1. Define the problem
# The quality of the wine is important for its competitiveness on the market. Hence wine producers would be interested to know what quality to expect from a wine. With this knowledge they might not put certain wines on the market because it would lead to low profitability, or even worse, monetary losses.
# Hence with this supervised machine learning model, we can help predict the red wine quality.

# %%
# Load libraries
import numpy
from numpy import arange
from matplotlib import pyplot
from pandas import read_csv
from pandas import set_option
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Prepare the data

# %%
# Load the dataset
import pandas as pd
red_wine = pd.read_csv('winequality-red.csv', sep = ';')

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# I notice that the range of values is different for the attributes. Hence it is advisable to standardize the features, which I will do later.

# %%
red_wine.shape
# Out:
# (1599, 12)

# %%
# Summarize data
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# correlation
set_option('precision', 2)
print(red_wine.corr(method='pearson'))
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity                  1.00         -2.56e-01         0.67
# volatile acidity              -0.26          1.00e+00        -0.55
# citric acid                    0.67         -5.52e-01         1.00
# residual sugar                 0.11          1.92e-03         0.14
# chlorides                      0.09          6.13e-02         0.20
# free sulfur dioxide           -0.15         -1.05e-02        -0.06
# total sulfur dioxide          -0.11          7.65e-02         0.04
# density                        0.67          2.20e-02         0.36
# pH                            -0.68          2.35e-01        -0.54
# sulphates                      0.18         -2.61e-01         0.31
# alcohol                       -0.06         -2.02e-01         0.11
# quality                        0.12         -3.91e-01         0.23
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
# histograms
red_wine.hist(sharex = False, sharey = False, xlabelsize = 1, ylabelsize = 1)
pyplot.show()

# %%
# density
red_wine.plot(kind='density', subplots=True, layout=(4,3), sharex=False)
pyplot.show()

# %%
import pandas as pd
pd.set_option('display.max_rows', 5000)
pd.set_option('display.max_columns', 5000)
pd.set_option('display.width', 5000)

# %%
# box and whisker plots
red_wine.plot(kind='box', subplots=True, layout=(4,3), fontsize = 8)
pyplot.show()

# %%
pd.set_option('display.expand_frame_repr', False)

# %%
# scatter plot matrix
scatter_matrix(red_wine)
pyplot.show()

# %%
# correlation matrix
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(red_wine.corr(), vmin=-1, vmax=1, interpolation='none')
fig.colorbar(cax)
ticks = arange(0,14,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(red_wine.columns)
ax.set_yticklabels(red_wine.columns)
pyplot.show()

# %% [markdown]
# I need training data to train the models and validation data to test the models.

# %%
# Split-out validation dataset
array = red_wine.values
X = array[:,0:11]
Y = array[:,11]
validation_size = 0.20
seed = 7
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=validation_size, random_state=seed)

# %% [markdown]
# ### 3. Spot Check Algorithms

# %% [markdown]
# I am trying several linear models (Linear Regression, Lasso, ElasticNet) and nonlinear models (KNeighborsRegressor, DecisionTreeRegressor, SVR).

# %%
# Test options and evaluation metric
num_folds = 10
seed = 7
scoring = 'neg_mean_squared_error'

# Spot Check Algorithms
models = []
models.append(('LR', LinearRegression()))
models.append(('LASSO', Lasso()))
models.append(('EN', ElasticNet()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('CART', DecisionTreeRegressor()))
models.append(('SVR', SVR(gamma='auto')))

# %%
# evaluate each model in turn
results = []
names = []
for name, model in models:
	kfold = KFold(n_splits=num_folds, random_state=seed)
	cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# Out:
# LR: -0.438750 (0.046907)
# LASSO: -0.653538 (0.042932)
# EN: -0.653406 (0.045364)
# KNN: -0.592741 (0.032934)
# CART: -0.715428 (0.092248)
# SVR: -0.508986 (0.053989)

# %%
# Compare Algorithms
fig = pyplot.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
pyplot.boxplot(results)
ax.set_xticklabels(names)
pyplot.show()

# %% [markdown]
# So far the best performing model is the Linear Regression. However, this has been with non standardized data. The standardization might change the performance and I will look into that.

# %%
# Standardize the dataset
pipelines = []
pipelines.append(('ScaledLR', Pipeline([('Scaler', StandardScaler()),('LR', LinearRegression())])))
pipelines.append(('ScaledLASSO', Pipeline([('Scaler', StandardScaler()),('LASSO', Lasso())])))
pipelines.append(('ScaledEN', Pipeline([('Scaler', StandardScaler()),('EN', ElasticNet())])))
pipelines.append(('ScaledKNN', Pipeline([('Scaler', StandardScaler()),('KNN', KNeighborsRegressor())])))
pipelines.append(('ScaledCART', Pipeline([('Scaler', StandardScaler()),('CART', DecisionTreeRegressor())])))
pipelines.append(('ScaledSVR', Pipeline([('Scaler', StandardScaler()),('SVR', SVR(gamma='auto'))])))
results = []
names = []
for name, model in pipelines:
	kfold = KFold(n_splits=num_folds, random_state=seed)
	cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# Out:
# ScaledLR: -0.438750 (0.046907)
# ScaledLASSO: -0.669340 (0.038886)
# ScaledEN: -0.669340 (0.038886)
# ScaledKNN: -0.479594 (0.050588)
# ScaledCART: -0.695835 (0.065599)
# ScaledSVR: -0.412628 (0.052220)

# %%
# Compare Algorithms
fig = pyplot.figure()
fig.suptitle('Scaled Algorithm Comparison')
ax = fig.add_subplot(111)
pyplot.boxplot(results)
ax.set_xticklabels(names)
pyplot.show()

# %% [markdown]
# SVR did the best after standardization having the lowest mean squared error.

# %% [markdown]
# ### 4. Improve Results

# %% [markdown]
# I attempt to improve the performance of the currently best model, SVR. I do this by trying different kernels and by using ensemble methods.

# %%
# SVR Algorithm tuning
scaler = StandardScaler().fit(X_train)
rescaledX = scaler.transform(X_train)
kernel_values = list(['linear', 'rbf', 'poly'])
param_grid = dict(kernel = kernel_values)
model = SVR()
kfold = KFold(n_splits=num_folds, random_state=seed)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scoring, cv=kfold)
grid_result = grid.fit(rescaledX, Y_train)

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.412721 using {'kernel': 'rbf'}
# -0.443353 (0.047408) with: {'kernel': 'linear'}
# -0.412721 (0.051887) with: {'kernel': 'rbf'}
# -0.595020 (0.215071) with: {'kernel': 'poly'}

# %% [markdown]
# The 'rbf' kernel yielded the best performance of the SVR.
# I will try now ensemble methods: boosting methods (Ada Boost and Gradient Boosting), and bagging methods (Random Forest and Extra Trees).

# %%
# ensembles
ensembles = []
ensembles.append(('ScaledAB', Pipeline([('Scaler', StandardScaler()),('AB', AdaBoostRegressor())])))
ensembles.append(('ScaledGBM', Pipeline([('Scaler', StandardScaler()),('GBM', GradientBoostingRegressor())])))
ensembles.append(('ScaledRF', Pipeline([('Scaler', StandardScaler()),('RF', RandomForestRegressor(n_estimators=10))])))
ensembles.append(('ScaledET', Pipeline([('Scaler', StandardScaler()),('ET', ExtraTreesRegressor(n_estimators=10))])))
results = []
names = []
for name, model in ensembles:
	kfold = KFold(n_splits=num_folds, random_state=seed)
	cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# Out:
# ScaledAB: -0.417432 (0.036200)
# ScaledGBM: -0.395879 (0.036376)
# ScaledRF: -0.392207 (0.061293)
# ScaledET: -0.361931 (0.065614)

# %%
# Compare Algorithms
fig = pyplot.figure()
fig.suptitle('Scaled Ensemble Algorithm Comparison')
ax = fig.add_subplot(111)
pyplot.boxplot(results)
ax.set_xticklabels(names)
pyplot.show()

# %% [markdown]
# The Extra Trees Regressor produced the best result, even better than the previous SVR. Hence I will tune it further.

# %%
# Tune scaled ScaledET
scaler = StandardScaler().fit(X_train)
rescaledX = scaler.transform(X_train)
param_grid = dict(n_estimators=numpy.array([50,100,150,200,250,300,350,400]))
model = ExtraTreesRegressor(random_state=seed)
kfold = KFold(n_splits=num_folds, random_state=seed)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scoring, cv=kfold, iid=True)
grid_result = grid.fit(rescaledX, Y_train)

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.333271 using {'n_estimators': 400}
# -0.337376 (0.051084) with: {'n_estimators': 50}
# -0.336016 (0.054874) with: {'n_estimators': 100}
# -0.334959 (0.052627) with: {'n_estimators': 150}
# -0.335051 (0.053557) with: {'n_estimators': 200}
# -0.334839 (0.053202) with: {'n_estimators': 250}
# -0.334560 (0.054281) with: {'n_estimators': 300}
# -0.333829 (0.054243) with: {'n_estimators': 350}
# -0.333271 (0.054094) with: {'n_estimators': 400}

# %% [markdown]
# Trying different number of estimators, the best choice was 400.

# %%
# Make predictions on validation dataset

# prepare the model
scaler = StandardScaler().fit(X_train)
rescaledX = scaler.transform(X_train)
model = ExtraTreesRegressor(random_state=seed, n_estimators=400)
model.fit(rescaledX, Y_train)
# transform the validation dataset
rescaledValidationX = scaler.transform(X_validation)
predictions = model.predict(rescaledValidationX)
print(mean_squared_error(Y_validation, predictions))
# Out:
# 0.26707597656250004

# %% [markdown]
# Finally I made predictions on the held out validation set using the best perofroming algorithms, with the best option of parameters. The MSE turned out to be 0.27.
